# %% [markdown]
# # 4D-Tesseractinator Demo
#
# This notebook launches the unified interactive dashboard for rotating a tesseract and viewing its projection, slice, or both.

# %%
from tesseractinator import create_interactive_dashboard

create_interactive_dashboard()
